# %%
import pandas as pd
# Set display options
pd.set_option('display.max_columns', None)      # used to show all the data column
pd.set_option('display.max_colwidth', None)     # used to show the entire content
pd.set_option('display.width', None)            # expanding width for long data sentences.

# %%
df = pd.read_excel('translation.xlsx')
# Out:
#                                                                                                          Shakespearean English  \
# 0                                                                                          I overheard him and his practices .
# 1  I have possessed your grace of what I purpose, and by our holy sabbath have I sworn to have the due and forfeit of my bond.
# 2                                                           and against your cony-catching rascals, bardolph, nym, and pistol.
# 3                                                      but for your words , they rob the hybla bees and leave them honeyless .
# 4                                                                                                                     O dear !
#
#                                                                                                                              Modern English
# 0                                                                                                           I overheard him and his plans .
# 1  your grace, I have told you what my intention is, and I have sworn by the holy sabbath to take what is owed to me by our legal contract.
# 2                                                                            and about your cheating scoundrels, bardolph, nym, and pistol.
# 3                                         but your words are as sweet as honey , you have stolen from the bees and left them with nothing .
# 4                                                                                                                               oh , dear !

# %%
from datasets import Dataset

dataset = Dataset.from_pandas(df)

from sklearn.model_selection import train_test_split
# Convert to a Hugging Face Dataset and split into training and evaluation
train_df, eval_df = train_test_split(df, test_size=0.1)  # 90% train, 10% eval
train_dataset = Dataset.from_pandas(train_df)
eval_dataset = Dataset.from_pandas(eval_df)

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration, Trainer, TrainingArguments


# Initialize the tokenizer
tokenizer = T5Tokenizer.from_pretrained("t5-small")
model = T5ForConditionalGeneration.from_pretrained("t5-small")

# Tokenization function
def preprocess_data(examples):
    inputs = ["translate Early English to Modern English: " + ex for ex in examples["Shakespearean English"]]
    targets = [ex for ex in examples["Modern English"]]

    model_inputs = tokenizer(inputs, max_length=128, truncation=True, padding="max_length")
    labels = tokenizer(targets, max_length=128, truncation=True, padding="max_length")

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# Tokenize the training dataset
tokenized_train_dataset = train_dataset.map(preprocess_data, batched=True)
# Tokenize the evaluation dataset
tokenized_eval_dataset = eval_dataset.map(preprocess_data, batched=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Map:   0%|          | 0/81068 [00:00<?, ? examples/s]
# Map:   0%|          | 0/9008 [00:00<?, ? examples/s]

# %%
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir="./t5-early-modern-translation",
    evaluation_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=5,
    weight_decay=0.01
)


trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_eval_dataset
)

# Start training
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241213_021814-cuwg01nm</code>
# Syncing run <strong><a href='https://wandb.ai/saikrishnakarnam19-university-of-colorado-denver/huggingface/runs/cuwg01nm' target="_blank">./t5-early-modern-translation</a></strong> to <a href='https://wandb.ai/saikrishnakarnam19-university-of-colorado-denver/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/saikrishnakarnam19-university-of-colorado-denver/huggingface' target="_blank">https://wandb.ai/saikrishnakarnam19-university-of-colorado-denver/huggingface</a>
#  View run at <a href='https://wandb.ai/saikrishnakarnam19-university-of-colorado-denver/huggingface/runs/cuwg01nm' target="_blank">https://wandb.ai/saikrishnakarnam19-university-of-colorado-denver/huggingface/runs/cuwg01nm</a>
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
#     <div>
#
#       <progress value='25335' max='25335' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25335/25335 37:12, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.368000</td>
#       <td>0.337701</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.351000</td>
#       <td>0.327367</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.345300</td>
#       <td>0.322176</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.335700</td>
#       <td>0.319569</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.334700</td>
#       <td>0.319007</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=25335, training_loss=0.3604200541961351, metrics={'train_runtime': 2263.5101, 'train_samples_per_second': 179.076, 'train_steps_per_second': 11.193, 'total_flos': 1.371486145216512e+16, 'train_loss': 0.3604200541961351, 'epoch': 5.0})

# %%
import torch

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def translate_function(early_english_sentence):

  # Preprocess the input and move to device
  input_ids = tokenizer("translate Early English to Modern English: " + early_english_sentence, return_tensors="pt").input_ids.to(device) # Move input_ids to the device

  # Generate the translation
  outputs = model.generate(input_ids)
  modern_translation = tokenizer.decode(outputs[0], skip_special_tokens=True)

  print("Modern English translation:", modern_translation)

# %%
translate_function("O, how I long to see thee again")
translate_function("Thou art as fair as the morning dew.")
translate_function("Hast thou seen the lady fair in yonder glen?")
translate_function("I shall not tarry, for time is fleeting")
translate_function("Oft have I heard thee speak of distant lands.")
translate_function("He doth protest too much, methinks.")
translate_function("Wilt thou be gone? It is not yet near day.")
translate_function("By my troth, I care not for such idle prattle.")
translate_function("Thy words are like honey, sweet and cloying.")
translate_function("Prithee, tell me thy tale of olden days.")
translate_function("All that glitters is not gold")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Modern English translation: oh, I have been waiting to see you again.
# Modern English translation: you are as good as the morning dew.
# Modern English translation: have you seen the lady in glen?
# Modern English translation: I will not tarry, because time is short.
# Modern English translation: I have often heard you speak of distant lands.
# Modern English translation: he is protesting too much, I think.
# Modern English translation: do you want to go? it is not yet near day.
# Modern English translation: I do not care about such a sloppy prattle.
# Modern English translation: your words are like honey, sweet and cloying.
# Modern English translation: please tell me your story of old times.
# Modern English translation: all that glitters is not gold.

# %%
file_path = "test.xlsx"  # Replace with your file path
data = pd.read_excel(file_path)

# %%
early_english_texts = data['Shakespearean English'].tolist()
reference_texts = data['Modern English'].tolist()

# %%
def generate_predictions(texts):
    predicted_texts = []
    for text in texts:
        inputs = tokenizer("translate Early English to Modern English: " + text, return_tensors="pt").to(device)
        outputs = model.generate(**inputs)
        predicted_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
        predicted_texts.append(predicted_text)
    return predicted_texts

# %%
predicted_texts = generate_predictions(early_english_texts)

predicted_texts
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ['no.',
#  'tell him, Catesby, that his ancient kings will be killed tomorrow at the',
#  'do not be afraid, sir. I have watched and traveled hard. I will sleep out',
#  'Goths have given me permission to sheathe my sword. Titus, un',
#  'no jokes like a fool.',
#  'oh, I am mocked, and you are sent here by some inc',
#  'Owen, Owen, the same, and his son-in-law Mortimer, and',
#  'not a whit.',
#  'show yourself how you feel the wretches, so that you can shake the',
#  'I thank God, I have been so well raised that I can write my name.',
#  'although I wish you died, I will not be the executioner.',
#  'why do you have to, sir? it is dinner time.',
#  'I do not know, madam. it is too bad, too bad.',
#  'who is your lord?',
#  'I would like to see them meet. that young Trojan ass, who loves the whore',
#  'where is he?',
#  'all of these writings tend to the great opinion that Rome holds about his name, and that',
#  'what, what, what? Ill luck, ill luck?',
#  'I will do more. although all I can do is nothing worth, since my penitence',
#  'if you are a man who hates all your human sons, you will be',
#  'oh, Lucillius, listen to a word with you.',
#  'you knew he was walking more dangerously than he was walking.',
#  'let him come.',
#  'but call the ambassador, and, as you please, let them have their answers every one of',
#  'all is well, sir. take my power to the court for yours.',
#  'for, to say the truth, although it is not wise to confess to an enemy of skill',
#  'go find him.',
#  'where is my knave, my fool?, go and call my',
#  'she is staying a little while, begging for a new way to mourn.',
#  'if he cried out, it would be a sight if one could match',
#  'the devil is a puritan who is, or anything he is constantly,',
#  '"I think it is a spell of great power, you see. you know the way',
#  '[reading] "sorted and consorted, contrary to your established edict and the can',
#  'I have been begging him to make his brain sick, and you are begging him to',
#  'please, be quiet and tell me what I will do to my lady. will I do to',
#  'are you so hot, sir? yet, Pucelle, keep your peace.',
#  'there is no lady living there. come on, meet me for this great errand',
#  "now, god forbid I say true! if you wrongfully use hereford's",
#  'let him land, and then he will be able to go to London solem',
#  'please, what do you think is his name?',
#  'if you were a poor man, you would have a thousand thousand friends, and',
#  'comfort me, my lord. remember who you are.',
#  'I will trust my resolution and my hands, no one about Caesar.',
#  'Zounds, it is just now at my elbow, persuading me',
#  'turn, slave, and fight.',
#  'and I am not a woman.',
#  'he is always a prologue to sleep.',
#  "you have sucked my daughter's heart with cunning, and swore",
#  'whereas I did not have a notorious ill, as a man kills',
#  'Tis : I hear him as if he was flattered.',
#  'these words of yours draw life-blood from my heart.',
#  "they are now holding them by force and not by right. since Richard, the first son'",
#  'oh, garden, and be a place of burying for all who live',
#  'and in her eyes there has appeared a fire to burn the errors that these princes hold',
#  'and earthly power shows that it is like God’s mercy when mercy seasons justice.',
#  'leave me alone to woo him.',
#  "then it would seem that Dobbin's tail is backward.",
#  'A gentle riddance.—draw the curtains, go.—all his complexion will',
#  'I will claim that promise to your Grace.',
#  'he called me in his shop and showed me silks that he had bought for me',
#  'oh, Cicero, I have seen the storms when the scol',
#  'frightened whisps are in the world. unnatural actions are',
#  'if the youth will come this way tomorrow, i will give him reasons for it.',
#  'I did not see her, but I looked at her.',
#  'I am not such a sick creature, I praise heaven.',
#  'i will go farther away.',
#  'I am happy you will ask me to stay, but do not wait, tell me',
#  'please, give me my previous answer. tell them to get me to do it and then sell',
#  'if fortune is so angry, it is just sluttish.',
#  'take a flight, take a flight, for shame!',
#  'Concolinel.',
#  'A beggar, brother?',
#  'I do not know him.',
#  "I swear, I thank him. he has asked me to a calf'",
#  'I do not love you, so do not pursue me.',
#  'poor rogues, please, tell me.',
#  'I do not have any part of the spirit that is in Antony.',
#  'my nyas?',
#  'and if my fortune is ever better, i will pay you for your debts.',
#  'as you love Phoebe, meet.',
#  'I will never care what I do, if this man comes to good.',
#  'who is coming to you? and what is your dispute? speak like a true knight,',
#  'you were best to go in.',
#  "look here, love. this diamond was my mother's. take it, heart. but",
#  'thanks for your good advice. you have harped my fear right away. but one more',
#  'it would be a tedious task to bring them to that prospect, I think.',
#  'who is there? come in. the wish deserves a welcome.',
#  'he was ten.',
#  'master, it is not time to chide you now.',
#  'to go out of my dialect, which you have so much.',
#  'would I rescue you from this reproach? why, but your scandal did not be wiped',
#  'will she leave to night?',
#  'I dare not swear that you love me, but my blood begins to flatter me',
#  'you are robbed! for shame, put on your gown. your heart is burs',
#  'Hubert, I think?',
#  'not now.',
#  'there is a hope of government in him, which, in his absence,',
#  'how are you?',
#  'please, sir, my ring or the chain. I hope you do not want to',
#  'but if you give him a good deal, there is gold, and my',
#  'she is asleep. good wench, let us sit down quiet, because we fear we wake',
#  'if they are half as good as mercy, they will be able to make them.',
#  'how many months do you want?',
#  'is not he?',
#  'I kneel here. if my will trespassed his love, either',
#  'are you with swords?',
#  'our blood is now calm, and, so long, health!',
#  'no, if they are never so ridiculous, then they should be unmanly, but',
#  'if you have the power to raise him, bring him here. and I will be',
#  'I am too suddenly, sirs, the warning is too sudden. but we will now',
#  'bravely, coragio!',
#  'why have you killed your only daughter so far?',
#  'all blessed secrets, all you unpublished virtues of the earth, spring with my',
#  'yes, because these slips have made him notice him for a long time. good',
#  'neither.',
#  'you are going to steal away bravely, boy.',
#  'is Banquo gone from court?',
#  'yes, but these english are shrewdly out of beef.',
#  'you came from France, I think?',
#  'young ravens must have food.',
#  'are you a little more happy than you are, being feared, than they are afraid',
#  'Lapis.',
#  'good sir, to the purpose.',
#  'but now, my lord, what do you say to my complaint?',
#  'as good a gentleman as the emperor.',
#  'oh, for the love of laughter, let him get his drum.',
#  'we wait on your Grace.',
#  'did you converse with this gentlewoman, sir?',
#  'how sweet you minister to love, that know love’s grief by his complexion!',
#  'oh god, if you love old men, if your sweet sway',
#  'and le coude?',
#  'where is he?',
#  'I know that there is some good news.',
#  'come, come, our empress, with her sacred wit to venge',
#  'not me.',
#  'I must attend the duke at dinner. I will be with you again at two of the',
#  'why, it is a boisterous and cruel style, a style for challenger',
#  'let it be. good night to everyone.',
#  "A friend should bear his friend's infirmities, but Brutus makes",
#  'i will be gentle and gentle in my words.',
#  'like a pair of loving turtle-doves who could not live as well day or',
#  'I know that the man who made us talk so much, looking before and after, did not',
#  'weary and old with service, to the mercy of a rude stream, that must for',
#  'it is my Lord of Berkeley, as I guess.',
#  'after so long grief, such nativity!',
#  'but for your part, it does not seem to me that you should have an inch of ground',
#  'and is not it well served as a sweet goose?',
#  'he is a king of the english, but his fisnomy is hot',
#  'she is tickled now. her fumes do not need to be swollen',
#  'what would you want me to do?',
#  'one day too late, I fear that I will be able to do all your happy days',
#  'I fear he will become the weeping philosopher when he grows old, because',
#  'oh, blood-besotted napolitan, outcast of',
#  'worthy Montano, you were not a civil. the gravity and stillness of',
#  'I can. at least, the whisper goes so. our last king, who appeared to',
#  'please tell me that he is well.',
#  'one would have a few wars with little cost.',
#  'and, Kate, when France is mys and I am yours, then yours is',
#  'please, see him presently discharged, because he is bound to sea and stays only',
#  'was it so late, friend, before you went to bed, that you lie',
#  'the barbaric Scythian, or the man who makes his generation messe',
#  'please, come up, I trow. is this the poultice for my',
#  'does my simple feature help you?',
#  'mistress, it is. sweet lady, entertain him to be my fellow servant to your lady',
#  '[to TRINCULO] here. then, tell me how you escaped.',
#  'i will be gone.',
#  'I do not know that, when he knows what I know.',
#  'it is not a matter of this kind. then you do not love me?',
#  'come on, trusty sword.',
#  'come on, wake up the snorting citizens with the bell or the de',
#  'Marcius!',
#  'how he describes himself!',
#  'good morning to your majesty and to my gracious mother.',
#  'but if you live to see what you are doing right away, then you will be left',
#  'so let us go, and hurry them with our fair intentions.',
#  'and even when your warlike father, like a child, told the sad story of my',
#  'A pox on your throat, you blasphemous, incharitable',
#  'sir, sir,',
#  '[as LUCENTIO] Well, sir, to do you courtesy,',
#  'the broken splintered, knitted, and joined together, must be',
#  'neither in time, no matter, or other circumstance. good morning, because, as I say',
#  'what is his strength by land?',
#  'please, sir Thomas. brothers, please come to the princes in our camp, do',
#  'is he who has the two beautiful daughters?',
#  'no more of that.',
#  'not me, my lord.',
#  'my lord, I have considered the title of this famous duke.',
#  'so i am.',
#  'so we will shadow the number of our host and make a mistake in reporting about us',
#  'that is the reason, fair nephew, that imprisoned me and held me all my',
#  'you mistook me, sir. I say she did nod. and you ask',
#  'so we will shadow the number of our host and make a mistake in reporting about us.',
#  'and will you, being a man of your breeding, be married under a bush like',
#  'she will take the action on her, father, if you advise it.',
#  'are they back?',
#  'and look, where Publius is coming to fetch me.',
#  'I will do your bid effectively.',
#  'well, time is the old justice that examines all of these offenders, and',
#  'has anyone in you, shepherd?',
#  'oh, Dionyza, such a piece of slaughter that the sun and',
#  'I wish your Grace would take me with you. Who is your Grace?',
#  'the goodness of the night will be on you, friends!',
#  'oh, now, oh! here comes a spirit of his, and',
#  'but your soldiers use him as a grace for meat, their talk at table, and their',
#  'what can you wish your enemy to be?',
#  "the late queen's gentlewoman, a knight's daughter, to be her mis",
#  'if not, the end of life will stop all bands. and i will die',
#  'at nine, we will meet again.',
#  'it is true.',
#  'and, they will take the offer of our grace. he and you, and you,',
#  'yes, to a niggardly host and more sparing guest. but even',
#  'and meritorious will be called that hand, a saint, that takes away your hate',
#  'so, to speak, and to avoid the first, and then, in speaking, not to',
#  'come on, my coach! good night, ladies. good night, sweet ladies. good night',
#  "but, Lepidus, go to Caesar's house.",
#  'where are your tenants and your followers?',
#  'yes, every inch a king.',
#  'the blood weeps from my heart when I shape, in imaginary form, the un',
#  'but small to bigger things must give way.',
#  'for government, though high and low and lower, is divided into parts, and is a',
#  'I wish you were bathed in a gentle bath, but I would never deny',
#  'I never saw her until now.',
#  'and who is your deer?',
#  'every jack-slave has his belly full of fighting, and I must go up and',
#  'I think the wall should curse again, since it is sensible.',
#  'but insolent, oh, come with pride, ambitious past all thinking, self',
#  'no, let me know, and knowing what I am, I know what she will be.',
#  'where is all this going?',
#  'my mistress is in love with a monster.',
#  'then, my queen, we are sad, in silence, after the night',
#  'he is now as brave as Hercules, who only tells a lie',
#  'Caesar speaks.',
#  'I know that well enough.',
#  '"Here was your father\'s bed, here in my breast. you are the next',
#  'and live a coward in your own respect, and if you do not want to',
#  'no, sometimes more feet than shoes, or shoes like my toes look through the over',
#  'and like a bated and retired flood, leaving our rank and our irregular course,',
#  'oh, oh!',
#  'how!',
#  '.........',
#  'the constables have delivered her to me, and she will have enough cheer, I assure',
#  'please, my order is here, and Sir John Stanley is appointed to take her with him to',
#  'go.',
#  'no contraries hold more antipathy than I and such a knave.',
#  'Aaron, a thousand deaths would I like to kill her whom I love.',
#  'York set him on to fight and die in shame. that, if Talbot was killed',
#  'the Lord Grandpre.',
#  'he is terrified and despairing Henry!',
#  'she lives, master shallow.',
#  'you were born of a woman. but I smile at swords, weapons laugh to shame',
#  'but why should honor be more honest? let it go.',
#  'come on, you are a transgressing slave. go away!',
#  'you will be the mother of a king again, and all the ruins of distress',
#  'if signor Leonato was her father, she would not have his head on',
#  'I have had the sweetest sleep and the most beautiful dreams I have ever had in a',
#  'why, hear, my masters, was it for me to kill the heir apparent?',
#  'no, I do not. I never gave you anything.',
#  'AEneas is a field, and I am a loyal member of many',
#  'no, madam, no.',
#  'what passion is on my tongue? I cannot speak to her, but she urged her to',
#  'see where she comes, dressed like a spring, and her subjects are beautiful, and her',
#  '[to NORFOLK, as well as NORFOLK] I am another.',
#  'oh, kiss me through the hole of this vile wall!',
#  'i will say "marry trap" with you if you run the nuthook',
#  'how have you slept, my lord?',
#  'i will drag you headlong by the heels to a dunghill which will be',
#  'yes, my lord.',
#  'do not you know?',
#  'he is a good man.',
#  'but that is not a marvel. he does not drink wine. there is never any',
#  'you will think it is strange if I could marry her.',
#  'will I hear from you soon?',
#  'you drunken slave, I sent you for a rope and told you what purpose and what',
#  'you may hope that your father did not get you, that you are not the Jew',
#  'I do not know why he is coming.',
#  "oh, you infinite virtue, are you smiling from the world's great s",
#  'for learn this, silius : better to leave and be redeemed than to',
#  'then, my Lord of Warwick, judge you between us.',
#  'nothing but blood, the blood, and the most valuable blood of the country.',
#  'good morning, general.',
#  'goodbye, sweet lords.',
#  'now set the teeth and stretch the nostril wide, hold the breath and bend every spirit to',
#  'or would you want me to speak like a tyrant to their sex',
#  'is this the noble moor, whom our senate calls all in all',
#  'no, good lieutenant! please, sir, hold your hand. [staying',
#  'this speech of yours has moved me, and will do good.',
#  'i am so sorry, because let our finger ache and it makes our other health',
#  'you do not have any sense of it, Moth. I will speak to that l',
#  'A plague on you, murderers, traitors all!',
#  'and if he does not follow Bourbon now, let him go, and',
#  'please, good Camillo, do not be afraid. it is a sickness that does not',
#  'please, let us go, good monsieur.',
#  'come on, I wish your cambric were as sensible as your finger, so that you',
#  'my lord, he has made many tenders of his affection for me.',
#  'why do not you say that? what ransom must I pay?',
#  'come on, how would you praise me?',
#  'oh, poor Romeo! he is already dead, stabbed with',
#  'what is his offense?',
#  'when my heart, as if it were a sigh, would rive',
#  'I think this is the most villanous house in all the streets of London for fleas',
#  'we must obey the time.',
#  'what is the story of our cousin Buckingham?',
#  'will you come to bed, my lord?',
#  'our troops will be ready tomorrow.',
#  'what, jealous Oberon? Fairies, skip here. I have sworn that',
#  'the prince and Claudio promised to visit me at this time., you know your office',
#  'but how did she receive his love?',
#  'A man, if I live, and this, by, and without, on the instant',
#  'Ajax, your mind is clearer, and your virtues are better. whoever',
#  'so please, something touching the Lord Hamlet.',
#  'the king is not here.',
#  'I met him with a customary compliment.',
#  'was that done like Cassius?',
#  'he is my dear friend, please.',
#  '"No, no," she said, "no dame, after living, I will',
#  'if you want to implore it, then you will be free to live, but',
#  'but if I could, by the man who gave me life, I would attach you all',
#  'I would exult, man. you know, he brought me out of favor with',
#  'please, let us go, and let her joy be her raven-coloured love',
#  'she is my goods, my talons, she is my house, my household stuff',
#  'often the expectation fails, and often the most promise is there, and often the hope is cold',
#  'A bigger dare to our great enterprise than if the Earl were here, for men must',
#  'start, sir. you are my elder.',
#  'a sheep is very often straying, even if the shepherd is away for',
#  'forgive it!',
#  'he blows my beard off and blows it in my face?',
#  'he lives on mouldy stewed prunes and dried cakes. A captain? God',
#  'I am ashamed I gave up to them.',
#  'and when do you want to say that?',
#  'come on, let us go together.',
#  'i am going to kill the man who is backward now!',
#  'Sir John, Sir John, I know how to wrench the true cause the false way.',
#  'listen to each other, Guildenstern, and you too.',
#  'I was trained in the english court,',
#  'I will ask him to answer like himself.',
#  "the emperor's court is like the house of fame, the palace full of tongue",
#  'it is my destiny, it is not, it is not. no man is too good to',
#  'sorry!',
#  'Illo, ho, ho, my lord!',
#  'you drink the stale of horses and the gilded puddle that',
#  'I do not owe you anything until I receive the chain.',
#  'she is a very fresh and delicate creature.',
#  'but theirs is sweetened with the hope that I will have the benefit that I have.',
#  'but when they see his crest again, sir, and the man in blood,',
#  'A pound of that same merchant’s flesh is yours. the court gives it,',
#  'he does, he does. we will be revenged on him.',
#  'although his false finger has profaned the ring, I will not do his Julia',
#  'I must stop the court. to do it, or not, is certain to me that it',
#  'so, so, so, so!',
#  'i will stop after.',
#  'what, hmm, psalm!',
#  'by the apostle Paul, shadows have struck more terror to the soul of Richard Than.',
#  'I assure you, my lord.',
#  'Casca, be sudden, because we fear that we will not be able to prevent them',
#  'all hid, all hid, an old infant play. I sit here like a',
#  'A herald, oh!',
#  'was ever a man so beaten?',
#  'why, he who cuts off twenty years of life cuts off so many years of fear',
#  'my Lord Bassanio and my gentle lady, I wish you all the joy that you can',
#  'therefore it is best for the wise, if Don Worm, his conscience,',
#  'things are done well, and with a care, exempt themselves from fear. things are',
#  'where are our men?',
#  'and you, being in love, cannot see how to put on your hose.',
#  'but I bury them in your daughter’s womb, where, in that nest',
#  'and please tell me, how do you find the people who are interested in you, especially younger',
#  'and you have mercy too! I never lied to you in my life,',
#  'what is the news, my friend?',
#  'York, if you are right, I greet you well.',
#  'these are kind creatures. gods, what lies I have heard! our courtiers say everything',
#  'I do not blame her, she could say nothing less. she had the wrong. but what',
#  'go, sir, for all you are my man, go wait on my cousin Shallow',
#  'the words of honor are the best way to pierce the ear of grief. and',
#  'please, your highness, call the queen again.',
#  'to you, that is not true or graceless. when have I hurt you? when have',
#  'his unjust kindness, which would have ruined her love, has made her violent and un',
#  'oh, breath is breath, and breath is breath.',
#  'do not you know me yet?',
#  'if you say, I hope you will not kill me.',
#  'what good turn?',
#  'someone orders Buckingham to be brought to Salisbury. the rest of the time march on',
#  'yes, if this war is a good thing, a good reason to fight.',
#  'then, madam, I thought you would not return again.',
#  'if I stand here, I saw him.',
#  'god save you! Where is the princess?',
#  'my master calls me.',
#  'but did you see them dead?',
#  'I think it is good morning, is not it?',
#  'he has no right to swear, since he is not a true and lawful',
#  'he is married.',
#  'oh, drums!',
#  'oh god, what some men do, while some men leave to do! how some',
#  "no, it is yours, my own self's better part, my",
#  'but we all are men, in our own natures fragile, and capable of our flesh.',
#  'but, lords, in all our bloody massacre, I must admit that we',
#  "for God's sake, lords, give a signal to the fight.",
#  'fair desires, in all fair measure, guide them! especially to you, fair queen! fair',
#  'the lusty, lusty, and the lusty George? and where is',
#  'in the sweet channel of her bosom dropt.',
#  'now she is reviving joy, and flatters her that it is Adonis',
#  'the enemy is coming on in a gallant show.',
#  'your noble cousin, Harry Bolingbroke, kisses your hand.',
#  'i have been snuck in my own house with a thread?',
#  'oh, Lord, I must laugh. I swear at you with a proverb',
#  'this swollen passion is wrong, my lord.',
#  'it cannot be better than you have murdered him. so a murderer should look, so',
#  'I know my physic will work with him.',
#  'nurse!—what should she do here? I have to act alone. come, vial',
#  'it is a gallant child, and a person who is really physics the subject',
#  'very well.',
#  'and now my tongue is not used to me anymore than an unstringed viol or',
#  'he is greeted by a desperate train.',
#  'I will go with you.',
#  'if the cause was not in existence, she would be the adulteress.',
#  'I never saw such a huge billow, sir, as he sank',
#  'I cannot put on the gown, stand naked and scold them, for my wound',
#  'oh, Tamora, be called a gentle queen, and kill me in',
#  'mistress, do you still talk?',
#  'which does not pries to the interior, but like the martlet builds in the',
#  "now, please, my lord, let us see the devil's plan.",
#  'oh, Helena, goddess, nymph, perfect, divine! I',
#  'why did you go to dover?',
#  'I cannot tell if I should leave in silence or bitterly speak in your reproof',
#  'please rest, sir.',
#  'there is no mercy in the King.',
#  "or i will be yours, my fair, or not my father's. I",
#  'oh, fat! do not take away your heavy hand! Death is the fairest',
#  'of him, sir.',
#  'those who do not know the fools are pitying those villains who are punished',
#  'tell the king I would like to go to his leisure for a few words.',
#  'or your own eyes would have the lights they would have when you chid at Sir Pro',
#  'oh, do not handle the theme, to talk about hands, so we should remember',
#  'did not I dance with you in brabant once?',
#  'if you have any sound or voice, speak to me. if there is any good',
#  'is not the lady Constance in this army? I know she is not, because this match',
#  'very well.',
#  'so he will waste his money, weary his soldiers, and commit himself to',
#  'you cannot fear us, Pompey, with your sails.',
#  "do you meet me at Ninny's tomb straight away?",
#  'if I do not, do not trust me. take it as you want.',
#  'please, I say, I am a useless coward!',
#  'I did not see him since.',
#  'come on, where is this young gallant who is so eager to lie with his mother earth',
#  'this dream is all wrong. it was a beautiful and beautiful vision. your statue s',
#  'our bloods do not obey the heavens more than our courtiers seem to be as good',
#  'let us stay and hear the will.',
#  'Sir, it is a mystery.',
#  'now, Hamlet, where is Polonius?',
#  'how he glists my rust! and how pity makes my',
#  'I would have found it well done after that, but I must condemn it now. stop,',
#  'I fear that if your thoughts were sifted, the king, your sovereign',
#  'yes, madam, no one at all. what do you call this? go with them',
#  'Sir John Falstaff!',
#  'we have been guided by you, and you have never had any disagreement. a sudden foil',
#  'and now, this ornament makes me look dismal. and I will be able to make',
#  'speak yet. how did you get your fight?',
#  "what was done to Elbow's wife, that he has reason to complain about?",
#  'he seems to be a great authority.',
#  'I should know that voice. it should be. but he is drowned, and',
#  'I had everything that any inferior man could have bought at the market price.',
#  'i will, my lord.',
#  'my lord, this would not be believed in Venice, although I swear I',
#  'and do not let any man follow this deed.',
#  'I dare to do what I dare to do too well, I do not dare',
#  'you look, my son, in a strange way, as if you were dism',
#  'I say my prayers loudly.',
#  'I gave the doctor the same name!',
#  'will you write me a sonnet to praise my beauty?',
#  'their over-greedy love has swelled. he is',
#  'she calls her pride plain, and she is a good man.',
#  'if he could fight himself, some of us would lie low.',
#  'and as he stooped back to take it up, the mad brideg',
#  'we will be married on Sunday.',
#  'oh, you are a disgraceful cousin! do not know that when',
#  'retire! we have been too far. Caesar himself has worked, and our oppressi',
#  'what do you say, uncle?',
#  'do not worry, i am not a swore oath. your',
#  'there was no link to the color of Peter’s hat, and Walter’s da',
#  'if I think so, I think the same of you.',
#  'you have broken the letter of your oath, which you will never have to',
#  'oh, peace, Paulina! you should take a husband by my consent',
#  'if you scold me into these dangers.',
#  'my father named me Autolycus, who was littered under Mercury, as',
#  'for the following, sir?',
#  'I will stop. but there is something on my cheek, and whispers in my ear',
#  '"she is a fool"?',
#  'then, affrighted by their bloody looks, he ran fearfully among',
#  'I will know him, I am sure of it. do not lie a night away from',
#  'many will swoon when they look at blood.',
#  "my lord, he is going to his mother's closet.",
#  'put your grace in your pocket, sir, for this one time, and let your flesh',
#  'that lord who advised you to give away your land, come here by me',
#  'come on, gentle my lord, look a little more beautiful.',
#  'here, claiming the Bastard would destroy it, came in a strong rescue.',
#  'believe me, sir, they are all together well.',
#  'here comes my lord.',
#  'you have a perfect thought. I will believe you are my friend,',
#  'you are a map of your sorrow, which is like a sign! when your poor',
#  'I would rather be in this choice than throw ames-ace for my life.',
#  'I did not see them.',
#  'do not let them live to taste this land’s growth, and that would hurt this fair',
#  'my Lord, what is the clock?',
#  'throw it under the hood.',
#  'oh, you are sick of self-love, Malvolio, and',
#  'the news is very good, my lord. Richard has not been far from here',
#  'I would be willing to do it, but my caution was more appropriate than the rebu',
#  'if you are ready, you will be ready, because your attacker is quick, skillful',
#  "they meet you with their hearts' thanks. both sides are equally happy. here I will sit",
#  'he loves to hear that unicorns can be betrayed by trees, bears',
#  'shame, and eternal shame, nothing but shame!',
#  'what, do you roar before you are pricked?',
#  'he is fathered, and yet he is not fathered.',
#  'make sure that the peace of the country is fair.',
#  "I remember this man since he was a farmer's eldest son.",
#  '( aside ) Oh, for a stone-bow, to hit him in the eye',
#  'I loved you ever.',
#  'yes, so the turn was served.',
#  'great god of heaven, say amen to all! but tell me, is young George Stanley',
#  'the weakest fruit drops to the ground, and so let me.',
#  '[to himself] to prove you are a cipher.',
#  'do not want to ally my rages and revenge with your colder reasons.',
#  'give him as much as you want to make him a royal man and send him back to',
#  'we must do something, and i will do it.',
#  'so proudly he would disdain the ground.',
#  'did you see his lip and eyes?',
#  'i will give you the time to speak freely.',
#  'I do not know. here he is, and here I give him.',
#  '"Mongst friends, if brothers.',
#  'and so, like a coward of a traitor, he sl',
#  'I cannot heave my heart into my mouth.',
#  'come from your ward, because I can here disarm you with this stick and make',
#  '— Boy, stand aside.',
#  'sir, now is your place.',
#  'I saw the wound, I saw it with my eyes, and I saw it with my eyes',
#  'yes, that is all, la! but I will not put my finger in the fire,',
#  'to say you do not, tell me that.',
#  'if he is absent, bring his brother to me.',
#  'i will be bold to leave you.',
#  'but he was there to end where he was to start and give away the benefit of',
#  'Sir Eglamour, I would go to Valentine, to mantua, where',
#  'from there he returned, his brows were bound with oak. I tell you,',
#  'the unfirm King is divided into three, and his coffers are filled with hollow poverty',
#  'poor man never joyed since the price of oats rose. it was the',
#  'yes, that would be known.',
#  'now, hercules will be your speed, young man!',
#  'so we, covered in the black mantle of the night, can beat down the guard',
#  'unless he has a fancy to this foolery, as it appears he has',
#  ", you supplie, pour l'amour de Dieu, me par",
#  'and waste huge stones with little water drops.',
#  'i will meet you at that place some hour later.',
#  'you offer it behind her back.',
#  'not a poor boy, sir, but a rich jew who would, si',
#  'Alexas!',
#  'was the crown offered him three times?',
#  'oh, a great young man!',
#  'do not bother us.',
#  'oh, the good gods!',
#  'out, strumpet! are you crying for him to my face?',
#  'but I ask you to be your grace, without any offence, and my conscience asks',
#  'yes, you have seen Cassio and she together.',
#  '"yes, do I," he said.',
#  'but who, ah, who had seen the moblèd queen—',
#  'but to the place where you are. it stands north-north-east and east',
#  'give me that sleeve and the wrenching iron.',
#  "and she thinks she is too long with her remaining. short time seems long in sorrow'",
#  'but as he said, your brother, he was criminal, in violation of the sacred',
#  'now i will tell her father of their disguising and pretended flight. who,',
#  'your voice will be as strong as any man can be in the process of removing new dig',
#  'I will not speak to her.',
#  'to find my uncle in the forest of Arden.',
#  'is the king stirring, worthy thane?',
#  'i have been napping, gentle love, and I have been sworn',
#  'thank you, sir.',
#  'go with me, and let us smother my damned son, which',
#  'why was that cry?',
#  '“Madam.”',
#  'by your pardon, sir, I was a young traveller. I was rather',
#  'my dearest cousin and my dearer lord?',
#  'poor and content is rich and rich enough, but riches are as poor as winter.',
#  'Harry of Hereford, Lancaster and Derby, get your lance, and God defend the right',
#  'come, Camillo. i will respect you as a father if you are going',
#  'will not you dance? how are you so angry?',
#  'then call them to our presence.',
#  'let me feel my sense in Lethe steep. if it is so to dream, let',
#  'we are poor citizens, the patricians good. what authority we have to take care of',
#  'weak shoulders, overgrown with bursts of grief, and arms, like',
#  'and see how he begins to make us strangers to his love.',
#  'my holy lord of Milan, I come from the king to learn how you dealt',
#  'then, Joan, discover your infirmity, which is a law that warrants your',
#  'that is not true.',
#  'come with me, and we will make a short work. because, by your permission,',
#  'was ever a man so tired?',
#  'is he alone?',
#  'and out of all these to restore the king, he advises a divorce.',
#  'how bad this taper burns!!! who is coming here? I think',
#  'turn your life into an hourglass, for which you can listen to this story.',
#  'if you are a good man, you will be happy.',
#  'master Ford, you must pray, and not follow the imaginations of your own heart. this',
#  'say I will love her forever.',
#  'I assure you, Carthage.',
#  'by the mess, before you see me, you will be slomber',
#  'what, should I groan and tell you?',
#  'I do not. I love him so much that he is stubborn, his checks, and',
#  'I cannot.',
#  'so he will die, and i will renew my mind in his fall. but,',
#  'great falsehood! why did he marry Fulvia and not love her?',
#  'as this pomp shows to a little oil and root. we make ourselves fools, to',
#  'if he will take it, then.',
#  'what men have you lost, Fluellen?',
#  'I have letters of the same tenor.',
#  'it comes on me., are you any thing?',
#  'I know it is a sin to be a mocker, but he!',
#  'please lead me on. I will call every house. I can command at least.',
#  'I will, my lord.',
#  'I think your greatness Hath should not be afraid. I tremble to think',
#  'if you swore against your oath and true loyalty, he would',
#  'I do not like your faults.',
#  'but my body is as hungry as the sea, and can digest as much.',
#  'our worse thoughts will be retreated.',
#  'Adonis, with a lazy spright, and with a heavy,',
#  'what handkerchief?',
#  'so far, my most feared lord, be my servant, as my true service',
#  'and your lips too, because I am sure I did it when I was first assured.',
#  'taste it first, as you are going to do.',
#  'either to die or to kill the society of men. therefore, fair Hermia,',
#  'are you the powerful pike?',
#  'what, weeping-ripe, my Lord Northumberland? think about the',
#  'I do not like your look, I promise you.',
#  'I never saw him sad. there is a frenchman his companion, an emin',
#  'is Claudio your enemy?',
#  'get to bed immediately, i will return forthwith. leave your attendant there, look',
#  'will nothing turn your unrelenting hearts?',
#  'the carrions of the island of Yond, desperate for their bones, are',
#  'A soothsayer asks you to beware of the ides of March.',
#  'you are a stool for a witch!',
#  'no, I added a lust to it.',
#  'where is Caius Marcius?',
#  'it is time and fortune to lie on a friend of mine, who, in hot blood',
#  'i am here, brother, full of heaviness.',
#  'thanks, gentle tribune, noble brother Marcus.',
#  'but, uncle, come close to me, to shed obsequious tears on this trunk',
#  'can honor be set to a leg? no. or an arm? no. or take',
#  'do not touch me.',
#  'he may do much, and his unkindness may defeat my life, but never stop',
#  'come, come, Antipholus, we are eating too late.',
#  'my clever instrument! Hark, Polydore, it sounds! but what time is',
#  'what should I do?',
#  'clubs, bills, and partisans! fight! beat them down! down with the Cap',
#  'your reassurance is too round. I would be angry with you if the time was',
#  'oh, sir, it would be a pity that you would get',
#  "when I lived in the world, I was the world's commander. by east, west",
#  'you will do little respect, show too bold malice against the grace and person of my master',
#  'take them in.',
#  'I wish we could. but I have a mind that fears him much,',
#  'my lord, prince Pericles is gone.',
#  'A pillow for his head. so, leave him all.',
#  'A man is a man who trusts you! I promised you and the chain, but',
#  'i am sure.',
#  '"I would be foolish, yes, to be put to the swords, and by two',
#  'Iago, never. like the icy sea, the icy current and the',
#  'only the adulterous Antony, most powerful in his abominations,',
#  'although he does not feel it, he is snuck up.',
#  "I assure you, as common as the way between Saint Alban's and London.",
#  'there is a part of a power already.',
#  'that is for good reason.',
#  'and there is Troilus who will not come far behind him.',
#  'well, you are going to call all the alehouses and ask those who are drunk',
#  'I do not have a conference as free and friendly as he used to.',
#  'it is a pity that the eagle should be mewed while',
#  'our hap is loss, our hope is only sad despair. Our ranks are broken, and',
#  'two thousand, fair woman. and i will tell you the hearing.',
#  'so deal with him as I prove to you.',
#  'I owe the most to you, Antonio, in money and in love.',
#  'the Duke himself, or any of my brothers of the state, can only feel this',
#  'we must not only arm the french,',
#  "ask the jew's house out.",
#  'if you are broken, you will be awed.',
#  'I would be friends with you and have your love, do not forget the shames you',
#  'he confessed to you, and gave you such a masterly report for your',
#  'go to my room, put on my clothes.',
#  'give it your hand.',
#  'my father, poorly led?',
#  '—How are you, Malvolio? how are you? what, man,',
#  'give me permission, Caesar.',
#  'Caesar and Antony have ever won more in their command than in their own hands. Sos',
#  'let Paris bleed. it is only a scar to scorn. Paris is blown',
#  'since I came to shore, I killed a man and feared I was scream',
#  'rogue, you have lived too long.',
#  'I cannot get any remedy against this use of the money. borrowing only lingers and',
#  'tell me that you overheard us, and tell her to steal into the sand',
#  'but if it were, she would not be worried about her.',
#  'and that is worse, the Lord Northumberland, his son young Henry Percy',
#  'I did, my lord.',
#  'i will, and I will, and I will not be able to punish both him',
#  '[to LUCILLIUS] Yield, or you die.',
#  'by heaven, I saw my handkerchief in the hand. oh, a',
#  'i will entertain Bardolph. he will draw, he will tap. said',
#  'I was sure your lordship did not give me it.',
#  'you see what mischief and what murder Hath has been committed by your enmity',
#  'I will look like if I look like a man moving. but I will not be',
#  'I will live by Nym, and Nym will live by me. is not this just',
#  'seek for him, so that his ungoverned rage will dissolve the life that wants the',
#  'oh, noble captain, come.',
#  'no, not for all the world.',
#  "oh, Joan, this kills your father's heart completely!",
#  'but here is a villain who would face me down. he met me on the mar',
#  'not yet, I beg you. I will always walk on my knees, and never',
#  'I would play incessantly on these jades, until they are not fenced in',
#  'you, who has no unkind mate to grieve you, would relieve me with',
#  'free, madam, no.',
#  'let us follow him, and pervert the actual wrath he has against himself',
#  'and thisbe, tarrying in mulberry shade, drew his',
#  'so say I amen.',
#  'oh, run, doll, run, run, good doll. come.',
#  'go with me, and i will tell you my story.',
#  'good sir John, I will not charge you for yours. I must tell you that',
#  'heigh, heigh, the devil rides on a fiddlestick.',
#  'I only frighten him once, and he will come within my view.',
#  'yes, I want him to sit under him. he is like a cold soldier.',
#  'remember March, remember the ides of March.',
#  'our house, my sovereign liege, is not worthy of the scourge of great',
#  'yes, sweetening, if we could do that, France would not be the place',
#  'oh, banish me, my lord, but do not',
#  'what is it that they do when they change us for others? is it sport? I think',
#  'if she did, I would be an eunuch. drag her husband to',
#  'but all these stupid obsequies are in vain. and to look at his',
#  'I beg your good will in this case.',
#  '—which I have set down in a quick order, and he will come to',
#  'we are mourning in black. why do not we mourn in blood?',
#  'yes, I offer it to him in the court. yes, twice the sum.',
#  'then stand with us.',
#  'do you know Gower?',
#  'it was nothing to geld a codpiece of a purse. I could have',
#  'where did he go? what makes him here? did he ask for me? where',
#  'sir, understand this of me, in a way that is clear.',
#  'do that, King Philip. do not hang in doubt.',
#  'am I in France?',
#  'he was damned for cozening the devil.',
#  'and this is my name. sweet Henry, please, give him a favor.',
#  'the terms of our estate may not be as dangerous as the one that is a king',
#  'you may think I do not love you.',
#  'infect her beauty, you fen-sucked fogs drawn by the powerful',
#  'one does not know how much a bad word can be a good thing to do.',
#  "no, Timon's money has paid his men their wages. he has never had",
#  'we are floating on such a full sea, and we must take the current when it serves',
#  'and, ignorant of his birth and his parents, he was a bricklayer when',
#  'go down with that sword! Tribunes, take a moment.',
#  'do not make it impossible to do anything that is unlike.',
#  'the poor shadows of Elysium, then, rest on your never-ending banks',
#  'my lord, I will be grateful. to any happy messenger from here.',
#  'peace, peace!',
#  'the night has been unruly. Where we lay, our chimneys were blown down',
#  'yes, and you, his servant, whose i have been a king of',
#  'speculation does not turn to itself, until it has traveled and is mirrored there where it',
#  'I have nothing to do with you.',
#  'god save you, sir.',
#  'calm down, fool! I have not done.',
#  'i will carry them here, but from their ashes will be re-ed',
#  'more calf, certain.',
#  'the fool follows after him.',
#  'for shame, come down. he made you the Duke of York.',
#  'kill, kill, kill, kill, kill him!',
#  'you would not listen to me, I asked you to do it at many times.',
#  'keep them away, Bardolph.',
#  'do not worry, man, you will lose nothing here.',
#  'please, let us go and find him. and quicken his heaviness with some',
#  'I was so afraid that I fled here, under the cover of a careful night, who',
#  'toad!',
#  'smile, gentle heaven! or strike, ungtle death! this world frowns',
#  'we are three of them.',
#  'sir, if you had told as many lies in his behalf as you have said in',
#  'you are pardoned, Isabel. and now, dear maid, be as free',
#  'there might be some women, Silvius, if they had marked him in parcels like',
#  'Marcius, it is true that you have told us recently. The Volsces are',
#  'our tongue is rough, coz, and my condition is not smooth, so',
#  'my life, sir!',
#  'A liberal hand. the hearts of old gave hands, but our new herald is hands',
#  'but where is the great alcides of the field?',
#  'are you begging to see the wrestling?',
#  'our scouts have found the adventure very easy. that as Ulysses',
#  'no, ask me if I can refrain from love. I love her very unfe',
#  'yes, but he will have only a year in all these ducats.',
#  'i will hide in the arbor.',
#  "and may it be that you forgot about your husband's job? will you, Antipho",
#  'but I, his brother, do not gain anything except growth, because his animals are as close',
#  'not on your sole, but on your soul, harsh Jew, you make your knife',
#  'believe me, you are wonderfully changed.',
#  'hail!',
#  'light is a fire, and fire will burn.',
#  'I think you are a bad husband, and I am glad to have you here as my',
#  'come on, come on.',
#  'do not believe me.',
#  'and did not I leave from there in rage?',
#  'she will be happy.',
#  'it is so, be sure of it.',
#  'you are the happier woman.',
#  'but what is going on? are not we all in love?',
#  'the enemy is growing every day.',
#  'love talks with better knowledge, and knowledge with more dear love.',
#  'speak lower, princes, for the queen is recovering.',
#  'if you were a good young man, I would make you believe I love you.',
#  'happy parents of such a good child.',
#  'it is false.',
#  'stop there, sir.',
#  'but the kindness is not a thing. "it would be better if she were kiss',
#  'but if you are out, sir, i will help you.',
#  'see, Caesar!',
#  'tell me, brother Clarence, what do you think of this new marriage with the lady grey',
#  'oh, a fair return of the banishment!',
#  'but come back to us quickly, because more is to be said and done.',
#  'I must go to the monument alone. I will wake Juliet within three hours. she will',
#  'take a break from the room and destroy your sight with a new.',
#  'I would be able to do it if I could spend time with such a',
#  'good fellows, ah, put up, put up. for, you know,',
#  'so, now dismiss your army when you want. hang up your ensign, let your',
#  "good night, but do not go to my uncle's bed.",
#  'is it a custom?',
#  'you say that is true when God wants you.',
#  'turn your complexion around, Patience, you young and rose-lipped cherubi',
#  'I will break the law of our order to the queen and get her to leave.',
#  'how!',
#  'he is pitying for your honor, and not a deserved ble',
#  'she is impudent, my lord, and was a common gameter',
#  'far away than near, be no closer.',
#  'but Brutus says he was ambitious, and Brutus is an honor',
#  'the right to die is a moderately sad thing, and the right to die is',
#  "there is the moral. now the l'envoy.",
#  'but he looks good.',
#  'give me some music. music, moody food from us who are in love.',
#  'what color, madam?',
#  'what is going on, my dear Othello? your dinner, and the generous islanders',
#  'I will know him, I am sure he is.',
#  'why, how could you know these men in Kendal green when it was so dark that',
#  'my treasure is in the harbor. take it. I followed the one I blushed to',
#  'if we remember the days we had never had, we would have been wrong, or we',
#  'there is a fire ready. and so, good Grumio, the news.',
#  'and you, enchantment. he is worthy of a herdsman',
#  'if he were where he thought, he would have thought that he was',
#  'i will teach you.',
#  'I have too few people to leave you.',
#  'goodbye, we are too precious to spend time with such a brabbler.',
#  '[to CORDELIA] then I am sorry. you have lost a father so',
#  'i will not have any of them.',
#  'it is better burn it now than curse it then. but be it. let it live.',
#  'I know her by her gait.',
#  'I hope your Majesty is a witness to me and will be a witness to',
#  'please keep your prayers!',
#  'Certes, she did. the kitchen vestal scorned you.',
#  '“Your grace will understand that when you receive your letter, I am very sick, but in',
#  'Adieu, do not let our old robes sit easier than our new',
#  'they will be satisfied. I will read enough, when I see the book, where all my',
#  'oh!',
#  'no, come on, let us go together.',
#  'let him be brought into the orchard here. is he still raged?',
#  'he is coming! Portotartarosa',
#  'this is a dull sight.',
#  'what rule, sir?',
#  'do we hear from you, Catesby, before we sleep?',
#  'I have seen a medicine that can breathe life into a stone, and make you dance',
#  'what should de honest man do in my closet? no honest man will come in my closet.',
#  'if I say, I saw such islanders, for, certes',
#  'give you good night.',
#  'I assure you that it is to knight you, Captain.',
#  'you must prepare to fight without Achilles.',
#  'in such a night, young Lorenzo swears he loved her well,',
#  'the lady is dead on my false accusation.',
#  "one sorrow treads on another's heel, so fast they follow. your sister's",
#  'they are in action.',
#  'so I will make sure he is safe, yes, and I will swear I killed him',
#  'I never hated you.',
#  "now, great Thetis' son!",
#  'oh damned Iago! oh, inhuman dog!',
#  'learn about the wise and wise : civet is a more swolle',
#  'I say again, in soothing them, we nourish our senate against the cock',
#  '"it is very sad to think about it. where is he, in his bed?',
#  'what is going on, my lord? I have been talking with a suitor',
#  '"it is certain there is not a boy left alive, and the cowardly',
#  'I could shake them off my coat. these bursts are in my heart.',
#  'therefore, your oaths are words and poor conditions, but they are not true',
#  'I do not know my name, my lord. Cressid was here',
#  'the gods defend him from such a shame!',
#  'he is claiming to have received no sinister measure from his judge, but he',
#  'oh, noble judge! oh, excellent young man!',
#  'I swear by my soul that there is no power in the tongue of man to change me.',
#  'yes, I think you could pardon him. and neither heaven nor man grieve at the',
#  'he is a poor man, to overshoot his troubles. he is',
#  'these signs will prevent the death or fall of kings.',
#  'yes, please let me go.',
#  'so, he may.',
#  'you are married?',
#  'and not a jot of "Tranio" in your mouth.',
#  'no? it is a plain case. the man who went, like a bass',
#  'please, sir.',
#  'she will not be as young as your former, but she will be as young as you,',
#  'oh, my dear discretion, how he is suited to his words',
#  'what has shattered them has given me fire.',
#  'with all this, we see cold wisdom waiting on superfluous folly.',
#  'we will do it tomorrow night.',
#  'for the boy, there is a good angel about him, but the devil is out',
#  'there to meet Macbeth.',
#  'that “may be” must be, love, on Thursday next.',
#  'he has enough colour, and the other has more colour, and is too flaming',
#  'that is a brave man, but he is proud of his vengeance,',
#  'where should we have our thanks?',
#  'and you',
#  'yes, why was he sent into England?',
#  'yes. you would never have seen him!',
#  'how is it, my noble lord?',
#  'if you use to beat me, i will start at your heel and tell you what',
#  'not until God makes men of some other metal than earth.',
#  'she hangs around his neck. if she is going to live, let her speak too',
#  'dear sir, I must try to get you to know more. remember us as a',
#  "Sir, he made a chimney in my father's house, and the bricks",
#  'her face was like a black eye to my eyes. the rest of you -',
#  'know the whole world, he is as brave.',
#  'what is this, Comelius?',
#  'but it is your grace that i have gotten from my mutest conscience to my',
#  'yes, I will wipe away all trivial facts, all books, all forms, all the',
#  'I have won a heaven on earth by wooing you.',
#  'what do you mean, sir, to give them this discomfort?',
#  '[to himself] it is the poisoned cup. it is too late.',
#  'Fulvia is dead.',
#  'he is very vile in the morning, when he is sober, and',
#  "they are both high-stomach's, and full of ire, in",
#  'I do not know.',
#  "the king's ship, the mariners, tell me how you have disposed",
#  'be careful when she weaved the silk with fingers long, small, white as milk.',
#  'this is his wife. that ring is a thousand proofs.',
#  'I kiss him forever.',
#  'the pedant, the braggart, the hedge-priest, the fool and',
#  'come on, will you go with me?',
#  'heavens make our presence and our practices pleasant and helpful to him!',
#  'please, my lord, it would not be a bad idea that he was',
#  'I have heard of your paintings too, well enough. God has given you one face and you',
#  'oh, I am almost dead!',
#  'and, as I told you, he put it by once.',
#  'oh, do not let virtue seek a reward for what it was. beauty,',
#  'this letter from Bellario, a young and learned doctor, is a good way',
#  'I know you did not, you are not such a villain. speak, because my heart',
#  'where is Antony?',
#  'will we call in the ambassador, my lord?',
#  'your heart desires you.',
#  'do that, my friends. see them well entertained.',
#  'oh my son, what is the theme?',
#  'as will the rest, so willeth Winchester.',
#  'who, without the means you talk about, did you ever know your beloved?',
#  'but everything goes well, but all our joints are whole.',
#  'he is a slander of mercy, because it is Clifford. who',
#  'dolor comes to him, indeed.',
#  'dear lad, believe it. they will be able to believe you are a man',
#  'what is Antony?',
#  'I go to take my stand to see him pass on to the Capitol.',
#  'signior, is your family in?',
#  'follow me.',
#  'since then, I never spoke with her, saw her, or heard from her, based',
#  'goodbye. go.',
#  'I come to her in white, and cry "mum," she cries "bud',
#  'his ascension is sweeter than our blest fields.',
#  'be as our gods will have it. it is only our lives to use our strongest hands',
#  'oh, Clitus!',
#  'and spit the wings from painted butterflies to fan the moonbeams from his sleeping',
#  'what is the news about the Rialto? who is he coming here?',
#  'I tell you, denied, my lord.',
#  'go to him, Dolabella, tell him to give up. because he is so',
#  'give me stinging nettles to my enemies. and when they pluck a',
#  'our kings are a king.',
#  'was there no other man in Rome to make a stale, but Saturnine?',
#  'if you tickle us, do not we laugh? if you poison us, do',
#  'I show it most of all when I show justice. then I pity those I do',
#  'please, and please.',
#  'he is better than rashness. tell him that we could have rebuked',
#  'he was greeted as mad as the vexed sea, singing al',
#  'oh, a slander! will we, on the ground of our land',
#  'as he loved me, I weep for him. as he was lucky,',
#  'what do you deserve from the fortune she sends you to prison here, my good friends',
#  'what should the king do now? must he submit? the king will do it',
#  'who is the soul who takes her heavy leave?',
#  'where are we left last?',
#  'you speak wonders.',
#  "which they will show at the very moment of Falstaff's meeting and our meeting.",
#  'who should we answer?',
#  'by heaven, you did. and to confirm it, you gave me this. but take it',
#  'madam, the lady Valeria is coming to visit you.',
#  'in the south suburbs, at the Elephant, it is best to stay.',
#  'do not go home.',
#  'are these wind instruments, please?',
#  'may it please your highness.',
#  'I am glad to hear it. then we will have to go to the end of our must',
#  'he tells her, no. he plans to hunt the boar tomorrow with certain',
#  'the ruddock would, with a charitable bill, shaming those rich',
#  'I will mount myself to your advantage on a courser, whose delightful steps will make',
#  'call me all my sad captains.',
#  'I will make bold to send them to you only for tonight. I must go aboard tomorrow.',
#  'speak.',
#  '"it is gone and will not answer.',
#  'I will drop on you in the drought of summer. I will melt the snow in winter with',
#  'sir, no more!',
#  'will I strike at it with my partisan?',
#  'you must speak louder. my master is deaf.',
#  'rise, Titus, rise. my empress has prevailed.',
#  'he refused, drooped, took it seriously, pushed it and',
#  ...]

# %%
pip install bert-score
# Out:
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.5.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.46.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.66.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.26.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: bert-score
# Successfully installed bert-score-0.3.13

# %%
pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 5.0 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2024.9.11)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.26.4)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (5.3.0)
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 12.8 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.0.0 sacrebleu-2.4.3

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import single_meteor_score
from bert_score import score as bert_score
from sacrebleu.metrics import CHRF
# from comet.models import download_model, CometModel



# Ensure necessary NLTK resources are downloaded
nltk.download('wordnet')

# BLEU Score
def calculate_bleu(reference_texts, predicted_texts):
    smoothie = SmoothingFunction().method4
    bleu_scores = [
        sentence_bleu([ref.split()], pred.split(), smoothing_function=smoothie)
        for ref, pred in zip(reference_texts, predicted_texts)
    ]
    average_bleu = sum(bleu_scores) / len(bleu_scores)
    return average_bleu

# METEOR Score
def calculate_meteor(reference_texts, predicted_texts):
    meteor_scores = [
        single_meteor_score(ref.split(), pred.split())
        for ref, pred in zip(reference_texts, predicted_texts)
    ]
    average_meteor = sum(meteor_scores) / len(meteor_scores)
    return average_meteor

# BERTScore
def calculate_bertscore(reference_texts, predicted_texts):
    P, R, F1 = bert_score(predicted_texts, reference_texts, lang="en", verbose=False)
    return F1.mean().item()  # Returning the average F1 score

# ChrF
def calculate_chrf(reference_texts, predicted_texts):
    chrf_metric = CHRF()
    chrf_scores = [
        chrf_metric.sentence_score(pred, [ref]).score
        for ref, pred in zip(reference_texts, predicted_texts)
    ]
    average_chrf = sum(chrf_scores) / len(chrf_scores)
    return average_chrf

# # COMET
# def calculate_comet(reference_texts, predicted_texts, source_texts):
#     model = load_model("Unbabel/wmt22-comet-da")  # Load COMET model
#     data = [
#         {"src": src, "mt": pred, "ref": ref}
#         for src, pred, ref in zip(source_texts, predicted_texts, reference_texts)
#     ]
#     results = model.predict(data, batch_size=8, gpus=1)
#     return sum(results["scores"]) / len(results["scores"])
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Assuming `reference_texts`, `predicted_texts`, and `source_texts` are defined and populated
average_bleu = calculate_bleu(reference_texts, predicted_texts)
average_meteor = calculate_meteor(reference_texts, predicted_texts)
average_bertscore = calculate_bertscore(reference_texts, predicted_texts)
average_chrf = calculate_chrf(reference_texts, predicted_texts)
# average_comet = calculate_comet(reference_texts, predicted_texts, source_texts)

# Printing the results
print("Average BLEU score:", average_bleu)
print("Average METEOR score:", average_meteor)
print("Average BERTScore (F1):", average_bertscore)
print("Average ChrF score:", average_chrf)
# print("Average COMET score:", average_comet)
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Average BLEU score: 0.09520507386173661
# Average METEOR score: 0.3092524629026468
# Average BERTScore (F1): 0.9014818072319031
# Average ChrF score: 36.357561500030684

# %%
model.save_pretrained("model/")
tokenizer.save_pretrained("model/")
# Out:
# ('model/tokenizer_config.json',
#  'model/special_tokens_map.json',
#  'model/spiece.model',
#  'model/added_tokens.json')

# %%
import pickle

with open("model.pkl", "wb") as f:
    pickle.dump(model, f)
